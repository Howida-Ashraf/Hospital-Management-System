# %% [markdown]
# <a href="https://colab.research.google.com/github/Howida-Ashraf/Hospital-Management-System/blob/main/Doctor_Department.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***part Howida

# %% [markdown]
# ##Doctor & Department
#
# Doctor Class
#
# Doctor ID
# Name
# Age
# Phone
# Department
#
# ##Department Class
#
# Department ID
# Department Name
# List of Doctors
#
# ##Main Features
#
# Add Doctor
# Add Department
# Search Doctor
# Display Doctor
# Display Department
# Connect Doctor with Department
# Validate Doctor data
#
# ##Relationship
#
# Department 1 -------- * Doctor
#
# One Department can have many Doctors, while each Doctor belongs to one Department.
#
# ##Validation
#
# Doctor ID cannot be empty.
# Doctor name cannot be empty.
# Age must be a valid positive number.
# Phone cannot be empty.
# Doctor ID must be unique.
# The selected Department must exist.

# %%
# %%writefile doctor.py

class Doctor:
    def __init__(self, doctor_id, name, age, phone, department):
        self.doctor_id = doctor_id
        self.name = name
        self.age = age
        self.phone = phone
        self.department = department
        self.appointments= []

    def display(self):
        print("Doctor ID:", self.doctor_id)
        print("Name:", self.name)
        print("Age:", self.age)
        print("Phone:", self.phone)
        print("Department:", self.department.name)

    def update(self, name, age, phone):
        self.name = name
        self.age = age
        self.phone = phone


    def display_appointments(self):
    if not self.appointments:
        print("No appointments found.")
        return

    print(f"Appointments for Dr. {self.name}:")

    for appointment in self.appointments:
        appointment.display_appointment()
# Out:
# Writing doctor.py

# %%
# %%writefile department.py

class Department:
    def __init__(self, department_id, name):
        self.department_id = department_id
        self.name = name
        self.doctors = []

    def add_doctor(self, doctor):
        self.doctors.append(doctor)

    def display(self):
        print("Department ID:", self.department_id)
        print("Department Name:", self.name)
        print("Doctors:")

        for doctor in self.doctors:
            print("-", doctor.name)
# Out:
# Writing department.py

# %%
# from doctor import Doctor
# from department import Department

# print("Modules imported successfully")
# Out:
# Traceback (most recent call last):
#
#   File f:\Python\Python314\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     from doctor import Doctor
#
#   File f:\Hospital_Project\doctor.py:25
#     if not self.appointments:
#     ^
# IndentationError: expected an indented block after function definition on line 24

# %%
departments = []
doctors = []

def add_department():
    department_id = input("Enter department ID: ")
    name = input("Enter department name: ")

    if department_id == "" or name == "":
        print("Invalid department data")
        return

    department = Department(department_id, name)
    departments.append(department)

    print("Department added successfully")


def add_doctor():
    doctor_id = input("Enter doctor ID: ")
    name = input("Enter doctor name: ")
    age = int(input("Enter doctor age: "))
    phone = input("Enter doctor phone: ")
    department_id = input("Enter department ID: ")

    if doctor_id == "" or name == "" or phone == "":
        print("Invalid doctor data")
        return

    if age <= 0:
        print("Invalid age")
        return

    department = None

    for d in departments:
        if d.department_id == department_id:
            department = d
            break

    if department is None:
        print("Department not found")
        return

    doctor = Doctor(doctor_id, name, age, phone, department)
    doctors.append(doctor)
    department.add_doctor(doctor)

    print("Doctor added successfully")


def search_doctor():
    doctor_id = input("Enter doctor ID: ")

    for doctor in doctors:
        if doctor.doctor_id == doctor_id:
            doctor.display()
            return

    print("Doctor not found")


def display_doctors():
    for doctor in doctors:
        doctor.display()
        print()


def display_departments():
    for department in departments:
        department.display()
        print()


add_department()
add_doctor()

print("\nAll Doctors")
display_doctors()

print("\nAll Departments")
display_departments()

print("\nSearch Doctor")
search_doctor()
# Out:
# Invalid department data
# Department not found
#
# All Doctors
#
# All Departments
#
# Search Doctor
# Doctor not found

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'doctor.py', 'department.py', '__pycache__', 'sample_data']
